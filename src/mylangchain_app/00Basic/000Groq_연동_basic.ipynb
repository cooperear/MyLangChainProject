# %%
print("Hello LangChain")
# Out:
# Hello LangChain

# %%
import os
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 

# load_dotenv(dotenv_path='.env')
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:10])
# Out:
# gsk_yRNqBi

# %%
# prompt + llm + output 

# prompt
prompt = ChatPromptTemplate.from_messages(
    [ ("system", "당신은 개발자입니다.") , 
     ("user", "{input}") ]
)
print(type(prompt))

print(prompt)
# Out:
# <class 'langchain_core.prompts.chat.ChatPromptTemplate'>
# input_variables=['input'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]

# %%
prompt_text = prompt.format(input="파이썬은 무엇인가요? 자세하게 설명해주세요")
print(type(prompt_text))
print(prompt_text)
# Out:
# <class 'str'>
# System: 당신은 개발자입니다.
# Human: 파이썬은 무엇인가요? 자세하게 설명해주세요

# %%
#llm = ChatOpenAI(api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-0125")

# Groq API를 사용하는 ChatOpenAI 인스턴스 생성
llm = ChatOpenAI(
    # api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    
    # model="moonshotai/kimi-k2-instruct-0905",
    model="openai/gpt-oss-120b",
    temperature=0.7
)
print(type(llm))
print(llm)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# client=<openai.resources.chat.completions.completions.Completions object at 0x00000233334D0770> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000233334D1220> root_client=<openai.OpenAI object at 0x00000233331135C0> root_async_client=<openai.AsyncOpenAI object at 0x00000233334D0FC0> model_name='openai/gpt-oss-120b' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.groq.com/openai/v1'

# %%
try:
    response = llm.invoke(prompt_text)
    print(type(response))
    print("응답:", response.content)
except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 응답: ## 파이썬(Python)이란?
#
# 파이썬은 **고수준(high‑level), 인터프리터 방식, 동적 타이핑(dynamic typing)** 을 갖춘 프로그래밍 언어입니다. 1991년 네덜란드의 Guido van Rossum이 발표했으며, 현재는 전 세계 개발자 커뮤니티와 기업에서 가장 많이 사용되는 언어 중 하나입니다.
#
# ---
#
# ## 1. 파이썬의 주요 특징
#
# | 특징 | 설명 |
# |------|------|
# | **읽기 쉬운 문법** | 들여쓰기(Indentation)로 블록을 구분해 코드 가독성이 뛰어남. `;` 나 `{}` 같은 구분자를 거의 사용하지 않음. |
# | **동적 타이핑** | 변수 선언 시 타입을 명시하지 않아도 되며, 런타임에 타입이 결정됨. |
# | **인터프리터 언어** | 코드를 바로 실행할 수 있어 개발·디버깅 속도가 빠름. (`python script.py` 로 실행) |
# | **멀티패러다임** | 절차적, 객체지향, 함수형 프로그래밍을 모두 지원. |
# | **풍부한 표준 라이브러리** | 파일 입출력, 네트워킹, 웹, 데이터베이스, 암호화 등 2,000개 이상의 모듈 제공. |
# | **플랫폼 독립성** | Windows, macOS, Linux, 그리고 모바일·임베디드 환경까지 거의 모든 플랫폼에서 동작. |
# | **확장성** | C/C++ 로 작성된 모듈을 쉽게 연결해 성능을 보강 가능 (`CPython`, `Cython`, `PyPy` 등). |
# | **대규모 커뮤니티** | PyPI(Python Package Index) 에는 300,000개가 넘는 서드파티 패키지가 존재. |
# | **오픈소스** | 자유롭게 사용·배포·수정 가능 (PSF 라이선스). |
#
# ---
#
# ## 2. 파이썬의 역사
#
# | 연도 | 사건 |
# |------|------|
# | **1980년대 후반** | Guido van Rossum, 네덜란드 암스테르담의 CWI(Center for Mathematics and Computer Science)에서 “ABC” 언어의 후속 프로젝트로 파이썬 개발 시작. |
# | **1991년** | 첫 번째 파이썬 0.9.0 공개 (예외 처리, 함수, 모듈 등 기본 기능 포함). |
# | **2000년** | 파이썬 2.0 발표 → 리스트 컴프리헨션, 가비지 컬렉션 등 추가. |
# | **2008년** | 파이썬 3.0 발표 → 문자열 처리 방식(Unicode 기본), `print` 함수화 등 비호환적 변화. |
# | **2010~2020년** | 데이터 과학, 머신러닝, 웹 프레임워크(Django, Flask) 등 다양한 분야에서 급성장. |
# | **2023년** | 파이썬 3.12 발표 → 패턴 매칭 개선, 성능 최적화 등. |
# | **현재** | 최신 안정 버전은 3.12.x이며, 3.13 베타가 활발히 테스트 중. |
#
# > **Tip**: 기존에 Python 2 코드를 유지보수해야 하는 경우, `2to3` 도구를 사용해 자동 변환을 시도할 수 있습니다. 하지만 대부분의 신규 프로젝트는 Python 3.x 를 사용합니다.
#
# ---
#
# ## 3. 파이썬 실행 방식
#
# 1. **인터프리터**
#    - `CPython` : 가장 널리 쓰이는 구현체 (C 로 작성).
#    - `PyPy` : JIT(Just‑In‑Time) 컴파일러 기반, 실행 속도가 빠름.
#    - `Jython` : Java 가상 머신 위에서 동작, Java와의 통합에 유리.
#    - `IronPython` : .NET 환경에서 사용.
#
# 2. **REPL** (Read–Eval–Print Loop)
#    ```bash
#    $ python
#    >>> print("Hello, world!")
#    Hello, world!
#    ```
#
# 3. **스크립트 실행**
#    ```bash
#    $ python my_script.py
#    ```
#
# 4. **바이트코드**
#    파이썬 코드는 먼저 `.py` → `.pyc` (바이트코드) 로 컴파일된 뒤, 가상 머신이 실행합니다.
#
# ---
#
# ## 4. 기본 문법 예시
#
# ### 4‑1. 변수와 자료형
#
# ```python
# # 정수, 실수, 문자열, 불리언
# a = 10          # int
# b = 3.14        # float
# name = "Alice" # str
# flag = True    # bool
#
# # 동적 타이핑: 같은 변수에 다른 타입을 할당 가능
# a = "Now a string"
# ```
#
# ### 4‑2. 컬렉션 (리스트, 튜플, 딕셔너리, 집합)
#
# ```python
# # 리스트 (mutable)
# numbers = [1, 2, 3, 4]
# numbers.append(5)       # [1, 2, 3, 4, 5]
#
# # 튜플 (immutable)
# point = (10, 20)
#
# # 딕셔너리 (키‑값)
# person = {"name": "Bob", "age": 30}
# person["age"] = 31
#
# # 집합 (중복 없는 원소)
# unique = {1, 2, 2, 3}   # {1, 2, 3}
# ```
#
# ### 4‑3. 제어문
#
# ```python
# # 조건문
# if a > 0:
#     print("양수")
# elif a == 0:
#     print("0")
# else:
#     print("음수")
#
# # 반복문
# for i in range(5):
#     print(i)          # 0 1 2 3 4
#
# while a < 10:
#     a += 1
# ```
#
# ### 4‑4. 함수와 람다
#
# ```python
# def greet(name: str) -> str:   # 타입 힌트 (선택 사항)
#     return f"Hello, {name}!"
#
# print(greet("Charlie"))        # Hello, Charlie!
#
# # 람다 (익명 함수)
# square = lambda x: x * x
# print(square(4))               # 16
# ```
#
# ### 4‑5. 클래스 (객체지향)
#
# ```python
# class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         raise NotImplementedError
#
# class Dog(Animal):
#     def speak(self):
#         return "멍멍!"
#
# class Cat(Animal):
#     def speak(self):
#         return "야옹!"
#
# dog = Dog("바둑이")
# cat = Cat("나비")
# print(dog.speak())   # 멍멍!
# print(cat.speak())   # 야옹!
# ```
#
# ### 4‑6. 모듈·패키지 사용
#
# ```python
# # math 모듈 (표준 라이브러리)
# import math
# print(math.sqrt(16))   # 4.0
#
# # 서드파티 패키지 설치와 사용
# # $ pip install requests
# import requests
# resp = requests.get("https://api.github.com")
# print(resp.status_code)   # 200
# ```
#
# ---
#
# ## 5. 파이썬이 많이 쓰이는 분야
#
# | 분야 | 대표 라이브러리 / 프레임워크 | 활용 예시 |
# |------|---------------------------|----------|
# | **웹 개발** | Django, Flask, FastAPI | REST API, 전자상거래 사이트 |
# | **데이터 과학** | NumPy, pandas, SciPy | 데이터 전처리, 통계 분석 |
# | **머신러닝/딥러닝** | scikit‑learn, TensorFlow, PyTorch | 이미지 분류, 자연어 처리 |
# | **자동화·스크립트** | `subprocess`, `os`, `shutil` | 파일 정리, 시스템 관리 |
# | **시스템 프로그래밍** | `socket`, `asyncio` | 네트워크 서버/클라이언트 |
# | **게임 개발** | Pygame, Panda3D | 2D/3D 게임 프로토타입 |
# | **임베디드** | MicroPython, CircuitPython | 마이크로컨트롤러 제어 |
# | **과학·공학** | Matplotlib, Bokeh, Plotly | 시각화, 시뮬레이션 |
# | **교육** | Turtle, Jupyter Notebook | 프로그래밍 입문, 인터랙티브 학습 |
#
# ---
#
# ## 6. 파이썬 개발 환경 설정 가이드
#
# 1. **Python 설치**
#    - 공식 웹사이트: <https://www.python.org/downloads/>
#    - Windows: 설치 시 “Add Python to PATH” 옵션 체크.
#    - macOS: Homebrew (`brew install python`) 로 설치.
#    - Linux: 배포판 패키지 매니저 (`apt install python3`, `yum install python3`) 사용.
#
# 2. **가상 환경(Virtual Environment) 활용**
#    ```bash
#    # venv 모듈 사용 (Python 3.3+)
#    python -m venv myenv
#    source myenv/bin/activate   # macOS/Linux
#    myenv\Scripts\activate.bat  # Windows
#    ```
#
# 3. **패키지 관리**
#    ```bash
#    pip install --upgrade pip          # pip 최신화
#    pip install numpy pandas           # 예시 패키지 설치
#    pip freeze > requirements.txt      # 현재 환경 저장
#    pip install -r requirements.txt    # 다른 환경에서 재현
#    ```
#
# 4. **코드 편집기/IDE**
#    - **VS Code** + Python Extension (인텔리센스, 디버거)
#    - **PyCharm** (Professional: 웹·데이터베이스 지원)
#    - **Jupyter Notebook / JupyterLab** (데이터 과학·시각화)
#
# 5. **코드 스타일**
#    - PEP 8 (Python Enhancement Proposal) → `flake8`, `black`, `isort` 로 자동 포맷팅.
#    - 타입 힌트 (`typing` 모듈) → `mypy` 로 정적 타입 검사.
#
# ---
#
# ## 7. 파이썬 학습 로드맵 (초급 → 고급)
#
# | 단계 | 목표 | 학습 내용 | 권장 자료 |
# |------|------|-----------|-----------|
# | **초급** | 기본 문법과 간단한 스크립트 작성 | 변수, 자료형, 제어문, 함수, 기본 모듈 | “점프 투 파이썬”, Codecademy Python |
# | **중급** | 객체지향, 파일 입출력, 예외 처리, 가상 환경 | 클래스·상속, `with` 문, `logging`, `requests` | “파이썬 완벽 가이드”, Real Python 튜토리얼 |
# | **전문** | 웹·데이터·머신러닝 등 분야별 응용 | Django/Flask, pandas, NumPy, scikit‑learn, asyncio | 공식 문서, Coursera/edX 강의, Kaggle 노트북 |
# | **고급** | 성능 최적화·배포·테스팅·CI | Cython, PyPy, Docker, pytest, GitHub Actions | “Fluent Python”, “Effective Python”, “Architecture Patterns with Python” |
#
# ---
#
# ## 8. 파이썬을 선택해야 하는 이유 (요약)
#
# 1. **생산성** – 짧은 코드와 풍부한 라이브러리로 빠른 프로토타이핑이 가능.
# 2. **다목적** – 웹, 과학, AI, 자동화 등 거의 모든 분야를 커버.
# 3. **커뮤니티** – 문제 해결을 위한 질문·답변이 풍부하고, 최신 기술이 빠르게 파이썬 패키지로 제공.
# 4. **교육 친화성** – 가독성 높은 문법 덕분에 프로그래밍 입문에 최적.
# 5. **기업 채택** – Google, Netflix, Instagram, NASA 등 대규모 시스템에서도 사용.
#
# ---
#
# ## 9. 간단한 프로젝트 아이디어 (실전 연습)
#
# | 난이도 | 프로젝트 | 핵심 파이썬 기능 |
# |--------|----------|-----------------|
# | **초급** | **Todo 리스트 CLI** | 파일 입출력, `argparse` 로 커맨드 라인 옵션 처리 |
# | **중급** | **웹 스크래퍼** | `requests`, `BeautifulSoup`, 예외 처리, CSV 저장 |
# | **전문** | **REST API 서버** | FastAPI, Pydantic 데이터 검증, async/await |
# | **고급** | **이미지 분류 모델** | PyTorch, 데이터 파이프라인, GPU 활용, 모델 서빙 (Docker) |
#
# ---
#
# ## 10. 마무리
#
# 파이썬은 **쉽게 배울 수 있으면서도 강력한** 언어입니다. 기본 문법을 익힌 뒤, **실제 문제를 풀어보는 프로젝트**를 진행하면 자연스럽게 실력이 성장합니다.
#
# > **Tip**: 학습 중에 “왜 이렇게 동작하지 않을까?” 하는 의문이 생기면, 공식 문서( <https://docs.python.org/3/> )와 **Stack Overflow** 를 적극 활용하세요. 두 곳은 파이썬 개발자의 가장 큰 나침반이 됩니다.
#
# 궁금한 점이 있으면 언제든 질문해 주세요! 🚀

# %% [markdown]
# # LCEL

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser
print(type(chain))
print(chain)
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000233334D0770>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000233334D1220>, root_client=<openai.OpenAI object at 0x00000233331135C0>, root_async_client=<openai.AsyncOpenAI object at 0x00000233334D0FC0>, model_name='openai/gpt-oss-120b', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://api.groq.com/openai/v1')] last=StrOutputParser()

# %%
response = chain.invoke({"input":"LCEL은 뭔가요?"})

# %%
print(type(response))
print(response)
# Out:
# <class 'str'>
# ## LCEL이란?
#
# **LCEL**은 **LangChain Expression Language**의 약자입니다.
# LangChain은 LLM(대형 언어 모델)을 활용한 애플리케이션을 보다 쉽게 구성·운영하도록 돕는 프레임워크인데, 최근에 **LCEL**이라는 도메인‑특화 언어(DSL)를 추가했습니다.
#
# LCEL은 “코드 없이도” 혹은 “짧은 파이썬 코드로도” 복잡한 **프롬프트 체인**, **툴 호출**, **조건 분기**, **루프** 등을 선언형으로 정의할 수 있게 해 주는 **표현식 언어**입니다.
#
# ---
#
# ## 왜 LCEL이 필요한가?
#
# | 전통적인 LangChain 사용법 | LCEL 사용 시 |
# |--------------------------|--------------|
# | 파이썬 클래스를 직접 상속·조합하고, `Chain`, `PromptTemplate`, `LLMChain` 등을 일일이 인스턴스화 | 한 줄 혹은 몇 줄의 선언형 표현식으로 동일 로직을 기술 |
# | 흐름 제어(조건·반복)를 구현하려면 `if/else`, `for` 등을 파이썬 코드로 직접 작성 | LCEL 문법 안에 `if`, `while`, `for` 같은 키워드가 내장돼 있어 직관적 |
# | 여러 체인을 연결할 때 `chain_a | chain_b` 같은 파이프라인 구성을 수동으로 관리 | `chain_a >> chain_b` 와 같은 연산자로 체인 연결을 선언 |
# | 디버깅·테스트 시 파라미터 전달·출력 확인이 번거로울 수 있음 | `debug()` 함수와 `print()` 같은 내장 헬퍼로 중간 결과를 바로 확인 가능 |
#
# 즉, **LCEL은 “코드 양을 줄이고 가독성을 높이며, 빠르게 프로토타입을 만들 수 있게”** 해 주는 레이어라고 생각하면 됩니다.
#
# ---
#
# ## LCEL의 핵심 문법
#
# | 구문 | 설명 | 예시 |
# |------|------|------|
# | `prompt("...")` | 프롬프트 템플릿 정의 | `prompt("You are a helpful assistant. {question}")` |
# | `llm("gpt-4o")` | 사용할 LLM 지정 | `llm("gpt-4o")` |
# | `>>` (파이프) | 앞 단계의 출력 → 뒤 단계의 입력 | `prompt(...) >> llm(...)` |
# | `if <cond> then <expr> else <expr>` | 조건 분기 | `if contains(question, "날씨") then weather_tool() else llm(...)` |
# | `for <var> in <iterable> do <expr>` | 반복 (주로 리스트/배치 처리) | `for item in items do llm(item)` |
# | `tool("<tool_name>")` | 외부 툴(검색, DB, API 등) 호출 | `tool("search")` |
# | `debug()` | 현재 컨텍스트(입력·출력) 출력 | `llm(...) | debug()` |
# | `output()` | 최종 결과 반환 (명시적) | `... >> output()` |
#
# > **주의**: LCEL은 파이썬 내부에서 문자열 형태로 파싱되며, `lc.run(expr)` 같은 함수로 실행됩니다. 따라서 파이썬 코드와 완전히 분리된 독립 언어는 아니지만, **선언형 DSL**이라고 부르는 것이 맞습니다.
#
# ---
#
# ## 실제 예시
#
# ### 1️⃣ 간단한 Q&A 체인
#
# ```python
# from langchain import lc
#
# expr = """
# prompt("You are a friendly assistant. 질문: {question}") >>
# llm("gpt-4o") >>
# output()
# """
#
# chain = lc.run(expr, {"question": "오늘 서울 날씨 알려줘"})
# print(chain)   # -> "오늘 서울은 구름이 많고..."
# ```
#
# ### 2️⃣ 툴 호출 + 조건 분기
#
# ```python
# expr = """
# prompt("사용자 질문: {question}") >>
# if contains(question, "날씨") then
#     tool("weather_api", location=extract_location(question)) >>
#     output()
# else
#     llm("gpt-4o") >>
#     output()
# """
#
# result = lc.run(expr, {"question": "내일 부산 날씨가 어때?"})
# print(result)   # 날씨 API 호출 결과가 반환됨
# ```
#
# ### 3️⃣ 배치 처리 (for-loop)
#
# ```python
# expr = """
# for q in questions do
#     prompt("Q: {q}") >>
#     llm("gpt-4o") >>
#     output()
# """
#
# batch = lc.run(expr, {"questions": ["서울 날씨?", "파리 여행 팁?", "파이썬 리스트 정렬"]})
# print(batch)   # 리스트 형태로 3개의 답변 반환
# ```
#
# ---
#
# ## LCEL을 언제 쓰면 좋은가?
#
# | 상황 | 권장 사용법 |
# |------|------------|
# | **프로토타입**: 아이디어를 빠르게 검증하고 싶을 때 | LCEL 한 줄로 체인 정의 → 즉시 실행 |
# | **비즈니스 로직이 복잡**: 여러 조건·루프·툴이 얽힌 경우 | 선언형 문법으로 흐름을 한눈에 파악 |
# | **협업**: 비개발자(기획자, 데이터 과학자)와 공유해야 할 때 | 파이썬 코드보다 읽기 쉬운 DSL 제공 |
# | **디버깅/테스트**: 중간 단계 결과를 자주 확인해야 할 때 | `debug()` 삽입만으로 손쉽게 로그 확인 |
#
# 반면 **고성능 최적화**가 필요하거나, **특수한 커스텀 클래스**를 직접 구현해야 할 경우는 기존 파이썬 기반 LangChain API를 그대로 사용하는 것이 더 유연할 수 있습니다.
#
# ---
#
# ## 시작하는 방법 (간단 가이드)
#
# 1. **설치**
#    ```bash
#    pip install langchain
#    ```
#
# 2. **LCEL 모듈 임포트**
#    ```python
#    from langchain import lc   # lc는 LangChain Expression Language 엔진
#    ```
#
# 3. **표현식 작성**
#    문자열 형태로 LCEL 코드를 만든 뒤 `lc.run()`에 전달합니다.
#    입력 변수는 딕셔너리 형태로 넘겨줍니다.
#
# 4. **실행 & 결과 확인**
#    `lc.run(expr, inputs)` 가 반환하는 값이 최종 출력(`output()`) 혹은 `debug()` 로 찍힌 중간값입니다.
#
# ---
#
# ## 참고 자료
#
# | 링크 | 내용 |
# |------|------|
# | **LangChain 공식 문서 – LCEL** | <https://python.langchain.com/docs/expression_language> |
# | **LCEL 튜토리얼 (Korean)** | <https://github.com/langchain-ai/langchain/tree/main/examples/korean/lcel> |
# | **GitHub – LangChain Expression Language 구현** | <https://github.com/langchain-ai/langchain/blob/main/langchain/expression_language.py> |
# | **블로그 포스트 – “LCEL로 체인 만들기”** | <https://medium.com/@langchain/lcel-intro> |
#
# ---
#
# ### 한 줄 정리
#
# > **LCEL은 LangChain 안에서 선언형으로 LLM 프롬프트, 툴 호출, 조건·반복 흐름 등을 간단히 정의할 수 있게 해 주는 ‘표현식 언어’**이며, 복잡한 체인을 짧은 문자열 하나로 구현해 프로토타이핑과 협업을 크게 효율화합니다.
