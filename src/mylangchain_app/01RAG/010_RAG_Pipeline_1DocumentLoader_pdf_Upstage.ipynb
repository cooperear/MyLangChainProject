# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# !poetry add pypdf=">=4.2.0,<5.0.0"
# !poetry add langchain-upstage
# Out:
# Updating dependencies
# Resolving dependencies...
#
# No dependencies to install or update
#
# Writing lock file
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - langchain-upstage
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.

# %% [markdown]
# #### PyPDFLoader 간단한 예제

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# w2

# %% [markdown]
# #### Upstage 를 사용한 RAG
# * ChatUpstage
# * UpstageEmbeddings
# * UpstageDocumentParseLoader

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

print("==> 1. 문서 로딩 → PDF 읽기...")
file_path = "../data/tutorial-korean.pdf"
loader = PyPDFLoader('../data/tutorial-korean.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
# ==> 1. 문서 로딩 → PDF 읽기...
#   총 39페이지 로드 완료

# %%
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # 청크 크기 (한국어 최적화)
    chunk_overlap=200,      # 중복 부분 (맥락 보존)
    separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
)
chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")

print(type(chunks),chunks)
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
#   66개 청크 생성 완료
#   평균 청크 길이: 688자
# <class 'list'> [Document(metadata={'producer': 'Acrobat Distiller with ezUniHFT', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2005-04-26T15:21:34+09:00', 'moddate': '2005-04-26T15:21:34+09:00', 'author': 'Owner', 'title': '<426C75654AC7D1B1DBC6A9C5E4B8AEBEF3B9AEBCAD283230292E687770>', 'source': '../data/tutorial-korean.pdf', 'total_pages': 39, 'page': 0, 'page_label': '1'}, page_content='1BlueJ 튜토리얼                   \n한국어 버전 2.0\nBlueJ Version 2.0.x 用\n                       \n          \nEnglish Version 2.0.1\nMichael Kölling\nMærsk Insitute\nUniversity of Southern Denmark \nKorean Version 2.0\n황석형 교수\nProject Member\nVer. 1.0 : 강석진, 민상호, 오경묵, 유형순, 이승환. Ver. 2.0 : 강원준\n 선문대학교 컴퓨터정보학부'), Document(metadata={'producer': 'Acrobat Distiller with ezUniHFT', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2005-04-26T15:21:34+09:00', 'moddate': '2005-04-26T15:21:34+09:00', 'author': 'Owner', 'title': '<426C75654AC7D1B1DBC6A9C5E4B8AEBEF3B9AEBCAD283230292E687770>', 'source': '../data/tutorial-korean.pdf', 'total_pages': 39, 'page': 1, 'page_label': '2'}, page_content='21. 서문 ·························································· ······························································· ······························· 4\n   1.1. BlueJ의 소개 ·············································· ······························································· ················· 4\n   1.2. 설명범위와 사용자 ············································· ······························································· ······ 4\n   1.3. 복제, 저작권과 배포 ············································ ······························································· ······ 4\n   1.4. 피드백 ···················································· ······························································· ······················· 4\n2. 설치 ·························································· ······························································· ······························· 5'), Document(metadata={'producer': 'Acrobat Distiller with ezUniHFT', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2005-04-26T15:21:34+09:00', 'moddate': '2005-04-26T15:21:34+09:00', 'author': 'Owner', 'title': '<426C75654AC7D1B1DBC6A9C5E4B8AEBEF3B9AEBCAD283230292E687770>', 'source': '../data/tutorial-korean.pdf', 'total_pages': 39, 'page': 1, 'page_label': '2'}, page_content='2. 설치 ·························································· ······························································· ······························· 5\n   2 .1 . Windows 에 설치하는 방법 ······················································ ··············································· 5\n   2 .2 . MacOS 에 설치하는 방법 ······················································ ··················································· 5\n   2.3. 리눅스/유닉스 및 기타 시스템에 설치하는 방법 ······························ ································· 6\n   2.4. 설치할 때 발생하는 문제점 ········································· ··························································· 6\n3. 시작하기 - 편집/컴파일/실행 ··········································· ····························································· 7\n   3.1. BlueJ 시작하기 ············································· ······························································· ·············· 7'), Document(metadata={'producer': 'Acrobat Distiller with ezUniHFT', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2005-04-26T15:21:34+09:00', 'moddate': '2005-04-26T15:21:34+09:00', 'author': 'Owner', 'title': '<426C75654AC7D1B1DBC6A9C5E4B8AEBEF3B9AEBCAD283230292E687770>', 'source': '../data/tutorial-korean.pdf', 'total_pages': 39, 'page': 1, 'page_label': '2'}, page_content='3.1. BlueJ 시작하기 ············································· ······························································· ·············· 7\n   3.2. 프로젝트 열기 ················································ ·······························································  ...

# %%
print("==> 3. 벡터화 → 임베딩으로 변환")
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

print("==> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
# 로컬 파일로 저장
vectorstore.save_local("faiss_index_upstage")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")
# Out:
# ==> 3. 벡터화 → 임베딩으로 변환
# ==> 4. 저장 → FAISS 벡터스토어에 저장
#  FAISS 벡터스토어 생성 완료 (66개 벡터)
# ===> 5. 검색 → 질문과 유사한 문서 찾기
#  Retriever 설정 완료

# %%
print("===> 6. 생성 → LLM으로 답변 생성")
llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.5
    )
print(llm)
# Out:
# ===> 6. 생성 → LLM으로 답변 생성
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001992F2D5A90> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001992F2D5D30> model_name='solar-pro' temperature=0.5 model_kwargs={} upstage_api_key=SecretStr('**********') upstage_api_base='https://api.upstage.ai/v1'

# %%
# 한국어 최적화 프롬프트
prompt_template = """
당신은 BlueJ 프로그래밍 환경 전문가입니다. 
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별 설명이 필요하면 순서대로 작성하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")
print(prompt)
# Out:
#  프롬프트 설정 완료
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n당신은 BlueJ 프로그래밍 환경 전문가입니다. \n아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.\n\n문서 내용:\n{context}\n\n질문: {question}\n\n답변 규칙:\n1. 문서 내용만을 근거로 답변하세요\n2. 단계별 설명이 필요하면 순서대로 작성하세요  \n3. 구체적인 메뉴명, 버튼명을 포함하세요\n4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요\n\n답변:'

# %%
# ===================================
# 7. QA 체인 생성
# ===================================
print("\n ===> 7.  QA 체인 생성...")
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("  RAG 파이프라인 구축 완료!")

# ===================================
# 8. 테스트 질문들
# ===================================
test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?", 
    "디버깅을 위해 중단점을 설정하는 방법을 알려주세요",
    "코드패드는 무엇이고 어떻게 사용하나요?",
    "애플릿을 만들고 실행하는 방법을 설명해주세요"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)

# ===================================
# 9. 질문 및 답변 실행
# ===================================
for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/5】
#  질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다. 문서 내용을 바탕으로 단계별로 설명드리겠습니다.
#
# ---
#
# ### 1. **클래스 아이콘을 통한 객체 생성 (기본 방법)**
#    - **단계 1**: 메인 윈도우 중앙의 클래스 아이콘(예: `Person`, `Staff`)에서 **마우스 오른쪽 버튼 클릭** (Mac의 경우 `Ctrl + Click`)합니다.
#    - **단계 2**: 팝업 메뉴에서 **생성자 함수**를 선택합니다.
#      - 대화상자가 나타나며, 생성할 객체의 이름을 입력받습니다. 기본 이름(예: `staff_1`)이 제공되므로 **OK 버튼**을 클릭해 객체를 생성합니다.
#    - **단계 3**: 생성된 객체는 **오브젝트 벤치(Object Bench)**에 표시됩니다(그림 4 참조).
#
# > 📌 **참고**: 추상 클래스(`<<abstract>>` 표기)는 객체를 생성할 수 없습니다.
#
# ---
#
# ### 2. **라이브러리 클래스로부터 객체 생성**
#    - **단계 1**: 상단 메뉴에서 **Tools → Use Libraries Class**를 선택합니다.
#    - **단계 2**: 팝업된 대화상자에 **패키지 이름까지 포함한 완전한 클래스명**을 입력합니다(예: `java.lang.String`, `java.util.ArrayList`).
#      - 최근 사용된 클래스 목록은 텍스트 필드에 자동 표시됩니다.
#    - **단계 3**: 엔터 키를 눌러 클래스의 **생성자 및 정적 메소드 목록**을 확인합니다.
#    - **단계 4**: 원하는 생성자 또는 정적 메소드를 선택해 호출합니다.
#
# ---
#
# ### 3. **정적 메소드 호출 (main 메소드 포함)**
#    - 클래스 아이콘에서 마우스 오른쪽 버튼 클릭 후, 팝업 메뉴에서 **정적 메소드**(예: `main`)를 직접 선택할 수 있습니다.
#    - `main` 메소드 호출 시, 매개변수로는 **`{"arg1", "arg2"}`** 형식의 문자열 배열을 입력할 수 있습니다.
#
# ---
#
# ### 요약
# - **일반 객체 생성**: 클래스 아이콘 → 생성자 선택 → 이름 입력 → OK
# - **라이브러리 객체 생성**: Tools → Use Libraries Class → 클래스명 입력 → 생성자 선택
# - **추상 클래스**: 객체 생성 불가능
#
# 문서에서 언급되지 않은 추가 기능은 "문서에서 찾을 수 없습니다"로 답변드립니다.
#
#  참조 문서:
#    1. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#    2. 페이지 35: 3610.6. 라이브러리 클래스로부터 객체생성하기 BlueJ 는 JDK에서 제공하는 라이브러리의 클래스들로부터 객체를 생성하기 위한 기능을  제...
#    3. 페이지 7: 83.2. 프로젝트 열기 프로젝트란, 관련 있는 여러개의 파일들을 묶어서 관리하기 위한 하나의 작업 단위를 말합니다.  BlueJ  프로젝트는 ...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 문서 내용에 따라 컴파일 오류 확인 방법을 단계별로 안내드립니다:
#
# 1. **에디터 창 자동 오픈 확인**
#    - 컴파일 오류 발생 시, BlueJ는 해당 오류가 발생한 클래스의 **에디터 창을 자동으로 엽니다**.
#    - 에디터의 **정보 창(information area)**에 오류 메시지와 발생 위치가 표시됩니다.
#    - 오류가 발생한 코드 라인은 반전(강조)되어 표시됩니다.
#
# 2. **도움말 버튼 활용 (문서 3.7절 참조)**
#    - 정보 창의 오른쪽 끝에 있는 **물음표(?) 버튼**을 클릭하면, 해당 오류 메시지에 대한 추가 설명이나 해결 방법을 확인할 수 있습니다.
#    - *예시*: "세미콜론 누락"과 같은 구문 오류 시, 물음표 클릭 → 관련 도움말 제공.
#
# 3. **프로젝트 툴바에서 전체 컴파일**
#    - 여러 클래스를 수정한 후 **프로젝트 윈도우 툴바의 Compile 버튼**을 눌러 전체 프로젝트를 컴파일합니다.
#    - 수정된 클래스는 아이콘에 체크 표시가 나타나며, 오류 발생 시 해당 클래스의 에디터가 열립니다.
#
# 4. **오브젝트 벤치 초기화 확인**
#    - 클래스 구현 변경 시 오브젝트 벤치의 기존 객체는 자동으로 삭제됩니다. 컴파일 후 새 객체를 생성해야 합니다.
#
# 5. **저장 관련 주의사항**
#    - 소스 코드는 에디터를 닫거나 컴파일 시 **자동 저장**되므로 별도 저장이 필요 없습니다.
#    - 단, 시스템 불안정이 우려될 경우 **Class 메뉴**에서 수동으로 저장할 수 있습니다.
#
# > 참고: 모든 오류 메시지에 도움말이 제공되지는 않으며, 일부는 추후 버전에서 추가될 예정입니다(문서 14페이지).
#
# 이 답변은 문서의 **3.6절(컴파일 하기)** 및 **3.7절(컴파일러 에러 도움말)** 내용을 근거로 작성되었습니다.
#
#  참조 문서:
#    1. 페이지 12: 클래스를 성공적으로 컴파일 하였다면 에디터를 닫으십시오.  프로젝트 윈도우에 툴바 역시 Compile 버튼을 가지고 있습니다. 이 컴파일 기능은...
#    2. 페이지 12: 13  노트 : 프로젝트를 처음 열었을 때 왜 클래스 아이콘에 체크표시가 되어있지 않은지 궁금할 수 있습니다. people  프로젝트 내의 클래...
#    3. 페이지 1: 3.7. 컴파일러 에러들에 관한 도움말 ······································· ··················...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 디버깅을 위해 중단점을 설정하는 방법을 알려주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 디버깅을 위해 **중단점(Breakpoint)**을 설정하는 방법은 다음과 같습니다. 문서 내용을 바탕으로 단계별로 설명드리겠습니다.
#
# ---
#
# ### **1. 중단점 설정 방법**
# 1. **소스 코드 편집기 열기**
#    - 디버거를 테스트할 클래스(예: `Demo` 클래스)를 더블클릭하여 소스 코드 편집기를 엽니다.
#
# 2. **중단점 영역 확인**
#    - 편집기 창 왼쪽의 회색 영역(줄 번호 옆)을 확인합니다.
#      (문서에서 "소스코드의 왼쪽 부분"이라고 명시된 영역)
#
# 3. **중단점 설정**
#    - 중단점을 설정할 줄(예: `loop` 메소드의 `for` 반복문 내 임의의 줄)에서 **왼쪽 버튼을 클릭**합니다.
#    - 작은 **stop 표시(●)**가 해당 줄에 나타납니다.
#      (문서: *"마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다."*)
#
# 4. **중단점 제거**
#    - 중단점을 해제하려면 동일한 줄을 다시 클릭하면 stop 표시가 사라집니다.
#
# ---
#
# ### **2. 중단점 사용 예시**
# - **예시 프로젝트**: `examples` 디렉토리의 `debugdemo` 프로젝트를 열고 `Demo` 클래스의 `loop` 메소드를 확인합니다.
# - **실행 방법**:
#   1. `Demo` 클래스에서 객체를 생성한 후 `loop(10)` 메소드를 호출합니다.
#   2. 프로그램 실행이 중단점에 도달하면 **디버거 창**과 **현재 실행 라인(반전 표시)**이 나타납니다.
#      (문서: *"프로그램 실행 중 중단점에 도달하게 되면 프로그램은 일시 중단 됩니다."*)
#
# ---
#
# ### **3. 주의사항**
# - 중단점은 **소스 코드의 실행 가능한 라인**에만 설정할 수 있습니다 (예: 변수 선언, 연산문 등).
# - 중단점 설정 후 반드시 **프로그램을 실행**해야 동작합니다.
#
# ---
#
# 문서에서 명시되지 않은 추가 기능(예: 조건 중단점)은 지원하지 않습니다.
# 문서 내용 외 정보는 **"문서에서 찾을 수 없습니다"**로 답변드립니다.
#
#  참조 문서:
#    1. 페이지 25: 267. 디버깅 이 절에서는, BlueJ의 디버깅에 관한 기능들 중에서 가장 중요한 측면을 소개합니다. 컴퓨터  프로그래밍 담당 선생님들은 첫 ...
#    2. 페이지 2: 37. 디버깅 ························································· ··············...
#    3. 페이지 25: 마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다. 바로 시도해 봅시다. Demo  클래...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 코드패드는 무엇이고 어떻게 사용하나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 코드패드(Code Pad)란?
# 코드패드는 **BlueJ에서 자바 코드(표현식/명령문)의 일부를 실시간으로 평가**할 수 있는 도구입니다. 프로그램 코드의 의미를 분석하거나, 특정 구문을 테스트할 때 유용하게 사용됩니다.
#
# ---
#
# ### 코드패드 사용 방법 (단계별 설명)
#
# #### 1. **코드패드 열기**
#    - **메뉴 경로**: `보기(Show) > 코드패드보기(Show Code Pad)`
#    - **위치**: BlueJ 메인 화면의 **오른쪽 하단**(오브젝트 벤치 옆)에 표시됩니다.
#    - **크기 조절**: 코드패드와 오브젝트 벤치 사이의 가로/세로 선을 드래그해 크기를 조정할 수 있습니다.
#
# #### 2. **기본 사용법**
#    - **입력**: 코드패드 영역에 자바 표현식 또는 명령문을 입력합니다.
#      - 예: `4 + 45`, `"hello".length()`, `Math.max(33, 4)`
#    - **실행**: 키보드 **Enter** 키를 눌러 코드를 실행합니다.
#      - 결과는 자동으로 화면에 표시되며, 타입 정보도 함께 출력됩니다.
#      - 오류 발생 시 에러 메시지가 나타납니다.
#
# #### 3. **객체 생성 및 활용**
#    - **객체 생성 표현식**:
#      - 예: `new Student()`, `"marmelade".substring(3,8)`
#    - **결과 확인**:
#      - 객체 생성 시 **작은 객체 아이콘**이 결과 라인 앞에 표시됩니다.
#      - 아이콘을 **더블클릭**하면 객체의 상태를 검사할 수 있습니다.
#    - **오브젝트 벤치로 이동**:
#      - 객체 아이콘을 **드래그**하여 오브젝트 벤치로 옮기면, 이후 작업에서 재사용할 수 있습니다.
#
# #### 4. **멀티라인 명령문 입력**
#    - **줄 바꿈**: 한 줄에 입력 후 **Shift + Enter**를 눌러 다음 줄로 이동합니다.
#    - **지역변수 사용**:
#      - 멀티라인 명령문 내에서 지역변수를 선언/사용할 수 있지만, **다른 라인에서 참조 불가**합니다.
#      - 예:
#        ```java
#        int sum = 0; Shift + Enter
#        sum = 10 + 20; Enter
#        ```
#      - 위 예시는 각 라인이 독립적으로 처리되므로 `sum` 변수가 유지되지 않습니다.
#
# #### 5. **사용자 입력 이력 기능**
#    - **이전 입력 재사용**:
#      - 키보드 **상하 화살표**를 눌러 이전에 입력한 코드를 다시 불러올 수 있습니다.
#      - 불러온 코드를 수정 후 재실행할 수도 있습니다.
#
# #### 6. **주의 사항**
#    - **변수 스코프**:
#      - 코드패드에서 선언한 변수는 **동일한 라인 내에서만 유효**합니다.
#      - 오브젝트 벤치의 객체는 **인스턴스 필드처럼 참조**할 수 있지만, 새 필드를 정의할 수는 없습니다.
#    - **객체 검사**:
#      - 코드패드 결과를 오브젝트 벤치에 추가하지 않고도 **더블클릭**으로 상태를 확인할 수 있습니다.
#
# ---
#
# ### 예시 시나리오
# 1. **코드패드 열기**: `보기 > 코드패드보기` 선택.
# 2. **객체 생성**: `new Student()` 입력 후 Enter → 객체 아이콘 생성.
# 3. **객체 검사**: 아이콘을 더블클릭하여 `Student` 객체의 필드/메소드 확인.
# 4. **오브젝트 벤치로 이동**: 아이콘을 드래그해 오브젝트 벤치에 추가.
# 5. **명령문 실행**:
#    ```java
#    String name = "BlueJ"; Shift + Enter
#    System.out.println(name); Enter
#    ```
#
# > 문서에서 명시되지 않은 기능(예: 디버깅 연동)은 **"문서에서 찾을 수 없습니다"**로 답변합니다.
#
#  참조 문서:
#    1. 페이지 1: 5.2. 클래스 만들기 ················································ ··················...
#    2. 페이지 20: 216. 코드패드의 사용 BlueJ 코드패드는 자바 코드(표현식과 명령문)의 일부분을 쉽고 빠르게 평가할 수 있는 기능을  제공합니다. 따라서,...
#    3. 페이지 36: 15. 코드패드로부터 객체를 오브젝트 벤치로 이동하기 위해서는 객체아이콘을 드래그 하십시오. 16. 코드패드에서 생성된 객체를 검사하기 위해서는...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 애플릿을 만들고 실행하는 방법을 설명해주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 애플릿 만들기 및 실행 방법 (BlueJ 기준)
#
# #### 1. **애플릿 만들기**
# 1. **새 클래스 생성**
#    - BlueJ 메인 창에서 **"New Class"** 버튼을 클릭합니다.
#    - 대화상자에서 클래스 이름을 입력하고, **"Type"** 드롭다운 메뉴에서 **"Applet"**을 선택합니다.
#    - **"OK"**를 클릭하여 애플릿 클래스를 생성합니다.
#      - 기본 템플릿이 제공되며, `paint` 메소드에 샘플 코드가 포함됩니다.
#
# 2. **코드 편집**
#    - 생성된 클래스를 더블클릭하여 에디터를 엽니다.
#    - `paint` 메소드를 수정하거나 추가 메소드를 구현하여 애플릿 기능을 완성합니다.
#      - 예: 사용자 입력 처리, 그래픽 렌더링 등.
#
# 3. **컴파일**
#    - 에디터를 닫고 **"Compile"** 버튼을 클릭하여 애플릿을 컴파일합니다.
#    - 클래스 아이콘에 `<<applet>>` 태그가 표시되는지 확인합니다.
#
# ---
#
# #### 2. **애플릿 실행하기**
# 1. **Run Applet 실행**
#    - 애플릿 클래스 아이콘을 마우스 오른쪽 버튼으로 클릭하여 팝업 메뉴를 엽니다.
#    - **"Run Applet"**을 선택합니다.
#    - 실행 옵션 대화상자가 나타납니다:
#      - **"Applet Viewer"**: JDK 내장 애플릿 뷰어로 실행 (권장, 버전 호환성 문제 없음).
#      - **"Web Browser"**: 기본 브라우저에서 실행 (Windows/MacOS는 시스템 브라우저, Unix는 설정 파일 참조).
#      - **"Generate HTML"**: 웹페이지만 생성하고 실행하지 않음.
#    - 원하는 옵션을 선택하고 **"OK"**를 클릭합니다.
#      - 애플릿 뷰어 또는 브라우저에서 애플릿이 실행됩니다.
#
# 2. **테스트 시 주의사항**
#    - **디버깅 제한**: 브라우저/애플릿 뷰어는 자체 JVM을 사용하므로, BlueJ의 중단점(breakpoint)이나 디버깅 기능이 작동하지 않습니다.
#    - **메소드 테스트**: 오브젝트 벤치에서 애플릿 객체를 생성한 후, 팝업 메뉴에서 특정 메소드를 직접 호출하여 테스트할 수 있습니다.
#
# ---
#
# #### 3. **디버깅이 필요한 경우**
# - **AppletWindow 클래스 활용**
#   - BlueJ에서 디버깅하려면 Michael Trigoboff의 **AppletWindow** 클래스를 사용해야 합니다.
#   - BlueJ 공식 홈페이지의 **Resources** 메뉴에서 다운로드 가능합니다.
#   - 이 클래스를 사용하면 BlueJ 환경에서 애플릿을 직접 실행하고 중단점/단계별 실행을 적용할 수 있습니다.
#
# ---
#
# #### 4. **예제 프로젝트 참고**
# - **appletdemo 프로젝트**
#   - BlueJ 설치 디렉토리의 `examples/appletdemo` 폴더를 엽니다.
#   - `CaseConverter` 애플릿을 실행해보면서 실행 절차를 익힐 수 있습니다.
#
# ---
#
# ### 요약
# 1. **New Class → Applet 선택**으로 생성.
# 2. **Run Applet** 메뉴에서 실행 환경 선택.
# 3. 디버깅 필요 시 **AppletWindow** 클래스 사용.
# 4. Unix 시스템에서는 설정 파일에서 브라우저를 지정해야 합니다.
#
# > 문서에서 명시되지 않은 내용은 "문서에서 찾을 수 없습니다"로 답변합니다.
#
#  참조 문서:
#    1. 페이지 32: 33마이크로소프트 윈도우즈나 MAC OS시스템에서, BlueJ 는 여러분의 기본 브라우저를 사용 합니다. 유닉스 시스템의 경우는, BlueJ 설...
#    2. 페이지 31: 329. 애플릿 만들기 9.1. 애플릿 실행하기     BuleJ 는 어플리케이션 뿐만 아니라 애플릿을 만들고, 실행할 수 있습니다. 예제(ex...
#    3. 페이지 2: 8. 독립형 어플리케이션 생성 ··············································· ···············...
#
# ----------------------------------------

# %%
from langchain_upstage import UpstageGroundednessCheck

groundedness_check = UpstageGroundednessCheck()

question = "BlueJ에서 객체를 생성하는 방법은 무엇인가요?"

retrieved_docs = retriever.invoke(question)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response = llm.invoke(f"{question} 관련 정보: {context}")

request_input = {
    "context": context,
    "answer": response.content
}

response = groundedness_check.invoke(request_input)
print(response)
# Out:
# grounded
