# %% [markdown]
# ## 0. 환경 구성

# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add langchain_community faiss-cpu

# %% [markdown]
# ### 2) OpenAI 인증키 설정
# https://openai.com/

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_y

# %%
EMBEDDING_MODEL_NAME = "bge-m3:latest"

# %% [markdown]
# #### RAG 파이프 라인
# * Load Data - Text Split - Indexing - Retrieval - Generation
# * OllamaEmbeddings 사용

# %%
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. Load Data
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

# print(type(documents),len(documents))
# pprint(type(documents[0]))
# print(documents[0])

# %%
# 2️. Text Split
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
split_docs = splitter.split_documents(documents)
print(len(split_docs),type(split_docs),len(split_docs))
print(split_docs[0])
# Out:
# 12 <class 'list'> 12
# page_content='제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 20., 2018. 3. 20., 2018. 12. 31., 2019. 12. 10., 2019. 12. 31., 2020. 6. 9., 2020. 12. 29., 2022. 8. 12., 2022. 12. 31., 2023. 8. 8., 2023. 12. 31.>
# 1. 「공익신탁법」에 따른 공익신탁의 이익
# 2. 사업소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득' metadata={'source': '../data/taxinfo.txt'}

# %%
# 3️. Indexing (벡터 저장)
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)
vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)
#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())

# 로컬 파일로 저장
vectorstore.save_local("faiss_index")

# 4️. Retrieval (유사 문서 검색) k: 질의와 가장 유사한 문서(청크) 6개를 찾아 반환하기
retriever = vectorstore.as_retriever(search_kwargs={"k": 6})
# **질문(쿼리)**에 대해 유사한 문서를 검색하는 역할
retrieved_docs = retriever.invoke("소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?")
print(retrieved_docs[0])
# Out:
# page_content='제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 20., 2018. 3. 20., 2018. 12. 31., 2019. 12. 10., 2019. 12. 31., 2020. 6. 9., 2020. 12. 29., 2022. 8. 12., 2022. 12. 31., 2023. 8. 8., 2023. 12. 31.>
# 1. 「공익신탁법」에 따른 공익신탁의 이익
# 2. 사업소득 중 다음 각 목의 어느 하나에 해당하는 소득
#     가. 논ㆍ밭을 작물 생산에 이용하게 함으로써 발생하는 소득
#     나. 1개의 주택을 소유하는 자의 주택임대소득(제99조에 따른 기준시가가 12억원을 초과하는 주택 및 국외에 소재하는 주택의 임대소득은 제외한다) 또는 해당 과세기간에 대통령령으로 정하는 총수입금액의 합계액이 2천만원 이하인 자의 주택임대소득(2018년 12월 31일 이전에 끝나는 과세기간까지 발생하는 소득으로 한정한다). 이 경우 주택 수의 계산 및 주택임대소득의 산정 등 필요한 사항은 대통령령으로 정한다.
#     다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양도로 발생하는 소득으로서 연 600만원 이하의 금액. 이 경우 조림기간 및 세액의 계산 등 필요한 사항은 대통령령으로 정한다.
#     바. 대통령령으로 정하는 작물재배업에서 발생하는 소득
#     사. 대통령령으로 정하는 어로어업 또는 양식어업에서 발생하는 소득
# 3. 근로소득과 퇴직소득 중 다음 각 목의 어느 하나에 해당하는 소득' metadata={'source': '../data/taxinfo.txt'}

# %%
# 5️. Generation (LLM 응답 생성)
#llm = ChatOpenAI(model="gpt-4o-mini")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response_context = llm.invoke(f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요? 관련 정보: {context}")
print('context 적용한 결과')
pprint(response_context.content)

response = llm.invoke(f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?")
print('context 적용하지 않은 결과')
pprint(response.content)
# Out:
# context 적용한 결과
# ('소득세법 제12조(비과세소득)는 “이 소득에는 세금을 매기지 않는다”는 케이스를 나열한 조문입니다.  \n'
#  '요지를 정리하면 다음과 같습니다(2024년 1월 1일 현행).\n'
#  '\n'
#  '1. 공익신탁 이익  \n'
#  '   - 「공익신탁법」에 따라 설립된 공익신탁이 발생시킨 이익.\n'
#  '\n'
#  '2. 사업소득 가운데  \n'
#  '   - 농지(논·밭)를 작물 생산에 맡겨 얻는 소득  \n'
#  '   - 1주택(공시가 12억 초과·국외주택 제외) 임대소득, 또는 연 2천만원 이하 임대소득(2018 과세기간까지)  \n'
#  '   - 대통령령이 정하는 농·어가 부업소득  \n'
#  '   - 전통주 제조소득  \n'
#  '   - 조림 5년 이상 임지의 목재를 벌채·양도해 생긴 소득(연 600만원 이하 한도)  \n'
#  '   - 대통령령이 정하는 작물 재백·어로·양식어업 소득\n'
#  '\n'
#  '3. 근로·퇴직소득 가운데  \n'
#  '   - 복무 중 병사 급여  \n'
#  '   - 법적 동원근무 급여  \n'
#  '   - 산재보험·근기법·선원법 등에 따른 요양·휴업·장해·유족·장의비 등 보상금  \n'
#  '   - 고용보험 실업급여·육아휴직급여 등  \n'
#  '   - 국민연금 사망일시금·반환일시금(사망 시)  \n'
#  '   - 국외·북한지역 근무로 법령이 정하는 급여  \n'
#  '   - 국가·지자체·사용자가 부담하는 건강·고용·장기요양보험료  \n'
#  '   - 법령상 연장·야간·휴일근로 수당(생산직 등 한정)  \n'
#  '   - 사내급식 또는 월 20만원 이하 식사대  \n'
#  '   - 출산·6세 이하 자녀 보육 관련 월 20만원 이내 급여  \n'
#  '   - 국군포로 보수·퇴직일시금  \n'
#  '   - 근로 대가로 받는 대학생 장학금(일정요건)  \n'
#  '   - 직무발명보상금(일정요건)  \n'
#  '   - 복리후생적 급여(대통령령이 정하는 범위)\n'
#  '\n'
#  '4. 연금소득 가운데  \n'
#  '   - 공적연금(국민·공무원·군인·사학·별정우체국 등) 유족·장애·장해·상이·순직·연계노령유족연금  \n'
#  '   - 산재보험 연금  \n'
#  '   - 국군포로 연금\n'
#  '\n'
#  '5. 기타소득 가운데  \n'
#  '   - 국가유공자 보훈급여·학습보조비, 북한이탈주민 정착금·보로금  \n'
#  '   - 국가보안법 상금·보로금  \n'
#  '   - 훈장 부상(副賞) 및 법령이 정하는 상금·부상  \n'
#  '   - 퇴직 후 받는 직무발명보상금(일정요건)  \n'
#  '   - 국군포로 위로지원금  \n'
#  '   - 국가지정문화재 서화·골동품 양도소득  \n'
#  '   - 박물관·미술관에 서화·골동품 양도소득  \n'
#  '   - 종교인소득 중  \n'
#  '     – 통계청 직업분류상 종교관련종사자가 받는 법령이 정하는 학자금  \n'
#  '     – 동일 종사자가 받는 식사·식사대  \n'
#  '     – 실비변상 성격의 지급액  \n'
#  '     – 출산·6세 이하 자녀 보육 관련 월 20만원 이하 금품  \n'
#  '     – 기획재정부령이 정하는 사택 제공 이득  \n'
#  '   - 위원회 위원 등이 받는 수당(보수를 받지 않는 자에 한함)\n'
#  '\n'
#  '즉, 위에 해당하는 소득은 모두 소득세를 부과하지 않는 ‘비과세소득’입니다.')
# context 적용하지 않은 결과
# ('소득세법에서 **비과세소득**은 말 그대로 **소득세를 부과하지 않는 소득**을 말합니다.  \n'
#  '즉, **과세 대상이 아닌 소득**이며, **신고 의무도 없고 세금도 내지 않습니다.**\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ 소득세법상 주요 비과세소득 (소득세법 §4 및 조세특례제한법 등)\n'
#  '\n'
#  '| 항목 | 내용 |\n'
#  '|------|------|\n'
#  '| **1. 이자·배당소득** | <ul><li>주택청약종합저축 이자</li><li>장기주택마련저축 이자</li><li>국민주택채권 '
#  '이자</li><li>우체국 예금 이자 (일정한도 내)</li><li>장기증권저축·ISA 계좌 이자 (한도 내)</li></ul> |\n'
#  '| **2. 근로소득** | <ul><li>근로자의 상여금 중 1회 500만원 이하, 연 2,500만원 이하</li><li>외국인 '
#  '근로자의 특별비과세 (일정 요건 충족 시)</li></ul> |\n'
#  '| **3. 연금소득** | <ul><li>국민연금, 공무원연금, 군인연금, 사학연금 등 **공적연금**</li><li>퇴직연금(IRP, '
#  'DC형) 수령 시 일시금 또는 연금 중 선택 가능 (일정 조건 하 비과세)</li></ul> |\n'
#  '| **4. 퇴직소득** | <ul><li>근로자 퇴직금 중 **5년 이상 근속 시 3천만원 + (근속년수 × 500만원)** 범위 내 '
#  '비과세</li></ul> |\n'
#  '| **5. 기타** | <ul><li>국가·지자체·공공기관이 주는 **포상금·장려금·보조금** (일정 '
#  '조건)</li><li>**재난지원금**, **코로나19 지원금** 등</li><li>**기부금 영수증**으로 공제받은 '
#  '금액</li><li>**장애인·국가유공자 등에 대한 보조금**</li></ul> |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ⚠️ 주의할 점\n'
#  '- **비과세 ≠ 면제세액**  \n'
#  '  비과세는 **세금 자체가 없는 것**, 면제세액은 **세금이 있지만 일부 감면**되는 것입니다.\n'
#  '- **일정 한도 초과 시 과세**될 수 있음 (예: ISA 계좌, 상여금 등)\n'
#  '\n'
#  '---\n'
#  '\n'
#  '필요하시면 **조세특례제한법**이나 **퇴직소득 비과세 한도 계산기**도 도와드릴 수 있어요.')

# %% [markdown]
# ### 개선한 Source - version1
# * Retriever 검색방법 개선
#     * search_type="mmr",  # 최대 다양성 검색
#     * search_kwargs={"k": 6, "fetch_k": 10}

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. 데이터 로드 (기존과 동일)
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

# 2. 텍스트 분할 개선
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # 크기 증가
    chunk_overlap=200,
    separators=["\n\n", "\n", " ", ""],  # 자연스러운 분할을 위한 구분자
    length_function=len,
    is_separator_regex=False,
)
split_docs = splitter.split_documents(documents)

# 3. 인덱싱 (벡터 저장)
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)
#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())

vectorstore.save_local("faiss_index")

# 4. 검색 개선
"""
    최대 다양성 검색(Maximum Marginal Relevance, MMR)
    MMR은 유사도가 높은 문서를 찾는 것을 넘어, 유사도와 다양성이라는 두 가지 기준을 모두 고려험
    - search_type="mmr": 검색 방식을 MMR로 지정합니다.
    - fetch_k: 일차적으로 질의와 유사한 문서 10개를 벡터 저장소에서 가져옵니다.
    - k: fetch_k로 가져온 10개의 문서 중에서 최종적으로 6개를 선택합니다. 6개를 선택할 때, MMR 알고리즘은 다음 두 가지를 고려함
        : 질의와의 유사도가 높고, 이미 선택된 다른 문서들과의 유사도가 낮은 (즉, 내용이 다양한) 문서
    * MMR의 작동 원리:
    - 질의와 가장 유사한 fetch_k개(10개)의 문서를 예비 후보군으로 가져옵니다.
    - 이 후보군 중에서 질의와 가장 유사한 문서 하나를 첫 번째 결과로 선택합니다.
    - 남은 후보군 중에서 질의와의 유사도는 높으면서 (관련성), 
      이미 선택된 문서들과의 유사도는 낮은 (다양성) 문서를 찾아 다음 결과로 추가함
    - 이 과정을 k개(6개)의 문서가 모두 선택될 때까지 반복합니다.        
"""
retriever = vectorstore.as_retriever(
    search_type="mmr",  # 최대 다양성 검색
    search_kwargs={"k": 6, "fetch_k": 10}  # 더 많은 결과 검색
)

# 5. 프롬프트 엔지니어링
def generate_prompt(query, context):
    return f"""다음은 소득세법 비과세소득 관련 조항입니다. 문맥을 고려하여 질문에 답변하세요.

[관련 조항]
{context}

[질문]
{query}

[답변 요구사항]
- 비과세소득 유형을 계층적으로 구분하여 설명
- 각 항목별 구체적인 조건 명시
- 법조문의 항, 호, 목 번호를 포함
- 500자 이내로 간결하게 요약"""

# 검색 및 응답 생성
query = "소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?"
retrieved_docs = retriever.invoke(query)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])

#llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)  # 창의성 낮춤
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
response = llm.invoke(generate_prompt(query, context))

print('개선된 결과:')
pprint(response.content)
# Out:
# 개선된 결과:
# ('소득세법 제12조 비과세소득은 5대 유형으로 계층화된다.\n'
#  '\n'
#  '1. 공익신탁 이익(제12조제1호)\n'
#  '\n'
#  '2. 사업소득(동조제2호)\n'
#  '- 논·밭 작물생산 소득(가목)\n'
#  '- 1주택(12억 이하, 국내) 임대소득 또는 연 2천만원 이하 주택임대소득(나목, 2018과세기한)\n'
#  '- 대통령령 농어가부업·전통주제조·작물재배·어로·양식 소득(다·라·바·사목)\n'
#  '- 조림 5년 이상 임지 벌채·양도소득 연 600만원 이하(마목)\n'
#  '\n'
#  '3. 근로·퇴직소득(동조제3호)\n'
#  '- 발명보상금·산학협력보상금(1·2호)\n'
#  '- 복리후생적 급여(저호)\n'
#  '\n'
#  '4. 연금소득(동조제4호)\n'
#  '- 공적연금 관련법 유족·장애·상이연금 등(가목)\n'
#  '- 산재보험·국군포로연금(다·라목)\n'
#  '\n'
#  '5. 기타소득(동조제5호)\n'
#  '- 보훈급여·북한이탈주민 정착금(가목)\n'
#  '- 상훈 부상·보상금(나·다목)\n'
#  '- 퇴직후 직무발명보상금(라목)\n'
#  '- 국군포로 위로금(마목)\n'
#  '- 문화재 서화·골동품 양도소득(바·사목)\n'
#  '- 종교인 학자금·식사대·실비변상·보육비(월 20만원)·사택이익(아목)\n'
#  '- 위원 수당(자목)')

# %% [markdown]
# ### 개선한 Source - version2
# * Prompt 개선

# %%
from langchain_openai import ChatOpenAI,OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_ollama import OllamaEmbeddings

from pprint import pprint

# 1. Load Data
loader = TextLoader("../data/taxinfo.txt", encoding="utf-8")
documents = loader.load()

print("=== 원본 문서 길이 ===")
print(f"전체 문서 길이: {len(documents[0].page_content)} 글자")

# 2. Text Split 개선
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,  
    chunk_overlap=150,
    separators=["\n\n", "\n", ". ", " ", ""]  # 법령 구조에 맞는 분리자
)
split_docs = splitter.split_documents(documents)

print(f"분할된 문서 수: {len(split_docs)}개")
print("=== 분할 예시 ===")
for i, doc in enumerate(split_docs[:3]):
    print(f"Chunk {i+1} ({len(doc.page_content)}글자): {doc.page_content[:100]}...")

# 3. Indexing
embeddings_model = OllamaEmbeddings(model=EMBEDDING_MODEL_NAME)

vectorstore = FAISS.from_documents(
    documents=split_docs, 
    embedding=embeddings_model
)

#vectorstore = FAISS.from_documents(split_docs, OpenAIEmbeddings())
vectorstore.save_local("faiss_index")

# 4. Retrieval 개선
retriever = vectorstore.as_retriever(
    search_type="similarity", 
    search_kwargs={"k": 6}  
)

query = "소득세법에서 비과세소득에 해당하는 소득은 무엇인가요?"
retrieved_docs = retriever.invoke(query)

print(f"\n=== 검색된 문서 ({len(retrieved_docs)}개) ===")
for i, doc in enumerate(retrieved_docs):
    print(f"문서 {i+1}: {doc.page_content[:200]}...")
    print("---")

# 5. Generation - 개선된 프롬프트
#llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0
)
context = "\n\n".join([f"[문서 {i+1}]\n{doc.page_content}" for i, doc in enumerate(retrieved_docs)])

# 개선된 프롬프트 - 더 구체적인 지시사항
improved_prompt = f"""
당신은 세무 전문가입니다. 아래 소득세법 제12조 조항을 바탕으로 질문에 답변해주세요.

질문: {query}

법령 조항:
{context}

다음 형식으로 답변해주세요:
1. 비과세소득의 정의
2. 주요 비과세소득 항목들을 다음과 같이 분류:
   - 사업소득 관련
   - 근로소득/퇴직소득 관련  
   - 연금소득 관련
   - 기타소득 관련
3. 각 항목별 구체적인 조건이나 한도액 명시

답변은 법조문을 인용하면서 구체적으로 작성해주세요.
"""

# 비교용 - 기존 방식
simple_prompt = f"소득세법에서 비과세소득에 해당하는 소득은 무엇인가요? 관련 정보: {context}"

print("\n=== 개선된 프롬프트로 답변 ===")
response_improved = llm.invoke(improved_prompt)
pprint(response_improved.content)

print("\n" + "="*50)
print("=== 기존 프롬프트로 답변 ===")
response_simple = llm.invoke(simple_prompt)
pprint(response_simple.content)

# 추가 개선: 다른 검색 방식 시도
print("\n" + "="*50)
print("=== 검색 방식 개선 테스트 ===")

# MMR(Maximum Marginal Relevance) 검색 - 다양성 확보
retriever_mmr = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={"k": 6, "fetch_k": 20}
)
retrieved_docs_mmr = retriever_mmr.invoke(query)
context_mmr = "\n\n".join([f"[문서 {i+1}]\n{doc.page_content}" for i, doc in enumerate(retrieved_docs_mmr)])

response_mmr = llm.invoke(f"""
{query}

법령 조항 (MMR 검색):
{context_mmr}

위 법령을 바탕으로 비과세소득 항목들을 체계적으로 정리해주세요.
""")

print("=== MMR 검색 결과 ===")
pprint(response_mmr.content)
# Out:
# === 원본 문서 길이 ===
# 전체 문서 길이: 4971 글자
# 분할된 문서 수: 8개
# === 분할 예시 ===
# Chunk 1 (738글자): 제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2....
# Chunk 2 (636글자): 다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양...
# Chunk 3 (792글자): 라. 「근로기준법」 또는 「선원법」에 따라 근로자ㆍ선원 및 그 유족이 받는 요양보상금, 휴업보상금, 상병보상금(傷病補償金), 일시보상금, 장해보상금, 유족보상금, 행방불명보상금, ...
#
# === 검색된 문서 (6개) ===
# 문서 1: 제12조(비과세소득) 다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다. <개정 2010. 12. 27., 2011. 7. 25., 2011. 9. 15., 2012. 2. 1., 2013. 1. 1., 2013. 3. 22., 2014. 1. 1., 2014. 3. 18., 2014. 12. 23., 2015. 12. 15., 2016. 12. 2...
# ---
# 문서 2: 다. 대통령령으로 정하는 농어가부업소득
#     라. 대통령령으로 정하는 전통주의 제조에서 발생하는 소득
#     마. 조림기간 5년 이상인 임지(林地)의 임목(林木)의 벌채 또는 양도로 발생하는 소득으로서 연 600만원 이하의 금액. 이 경우 조림기간 및 세액의 계산 등 필요한 사항은 대통령령으로 정한다.
#     바. 대통령령으로 정하는 작물재배업에서 발생하...
# ---
# 문서 3: 나. 「국가보안법」에 따라 받는 상금과 보로금
#     다. 「상훈법」에 따른 훈장과 관련하여 받는 부상(副賞)이나 그 밖에 대통령령으로 정하는 상금과 부상
#     라. 종업원등 또는 대학의 교직원이 퇴직한 후에 사용자등 또는 산학협력단으로부터 지급받거나 대학의 학생이 소속 대학에 설치된 산학협력단으로부터 받는 직무발명보상금으로서 대통령령으로 정하는 금액. ...
# ---
# 문서 4: 4) 종교관련종사자 또는 그 배우자의 출산이나 6세 이하(해당 과세기간 개시일을 기준으로 판단한다) 자녀의 보육과 관련하여 종교단체로부터 받는 금액으로서 월 20만원 이내의 금액
#     　　　　5) 종교관련종사자가 기획재정부령으로 정하는 사택을 제공받아 얻는 이익
#     자. 법령ㆍ조례에 따른 위원회 등의 보수를 받지 아니하는 위원(학술원 및 예술원의 회원...
# ---
# 문서 5: 더. 생산직 및 그 관련 직에 종사하는 근로자로서 급여 수준 및 직종 등을 고려하여 대통령령으로 정하는 근로자가 대통령령으로 정하는 연장근로ㆍ야간근로 또는 휴일근로를 하여 받는 급여
#     러. 근로자가 사내급식이나 이와 유사한 방법으로 제공받는 식사 기타 음식물 또는 근로자(식사 기타 음식물을 제공받지 아니하는 자에 한정한다)가 받는 월 20만원 이하의 ...
# ---
# 문서 6: 2) 대학의 교직원 또는 대학과 고용관계가 있는 학생이 소속 대학에 설치된 「산업교육진흥 및 산학연협력촉진에 관한 법률」 제25조에 따른 산학협력단(이하 이 조에서 “산학협력단”이라 한다)으로부터 같은 법 제32조제1항제4호에 따라 받는 보상금
#     저. 대통령령으로 정하는 복리후생적 성질의 급여
# 4. 연금소득 중 다음 각 목의 어느 하나에 해당하는 소득...
# ---
#
# === 개선된 프롬프트로 답변 ===
# ('1. 비과세소득의 정의  \n'
#  '소득세법 제12조는 “다음 각 호의 소득에 대해서는 소득세를 과세하지 아니한다”고 규정하면서, 법령이 정하는 일정한 '
#  '소득(이익·급여·보상금 등)에 대해 과세를 배제하는 제도를 두고 있습니다. 즉, 조세특례제한법 등 별도 법령이 아닌 소득세법 조문 '
#  '자체에서 직접 비과세 대상으로 명시한 소득을 말합니다.\n'
#  '\n'
#  '2. 주요 비과세소득 항목(분류)\n'
#  '\n'
#  '가. 사업소득 관련(제12조 제2호)  \n'
#  '1) 논·밭을 작물 생산에 이용하게 함으로써 발생하는 소득(가목)  \n'
#  '2) 1주택자의 주택임대소득  \n'
#  '   - 단, 제99조 기준시가 12억 초과 주택·국외 주택은 제외  \n'
#  '   - 2018년 12월 31일 이전 과세기간 한정, 총수입 2천만원 이하인 경우에만 비과세(나목)  \n'
#  '3) 대통령령이 정하는 농어가부업소득(다목)  \n'
#  '4) 대통령령이 정하는 전통주 제조소득(라목)  \n'
#  '5) 조림기간 5년 이상 임지의 임목 벌채·양도소득 → 연 600만원 이하 한도(마목)  \n'
#  '6) 대통령령이 정하는 작물재배업·어로·양식어업 소득(바목·사목)\n'
#  '\n'
#  '나. 근로소득·퇴직소득 관련(제12조 제3호 및 관련 조항)  \n'
#  '1) 복무 중 병(兵)이 받는 급여(가목)  \n'
#  '2) 법률에 따라 동원된 사람이 그 직장에서 받는 급여(나목)  \n'
#  '3) 산재보험법 요양·휴업·장해·간병·유족·장의비 등 급여(다목)  \n'
#  '4) 근기법·선원법상 보상금류(요양·휴업·상병·일시·장해·유족·장의비 등)(라목)  \n'
#  '5) 국군포로법상 보수·퇴직일시금(제3호 버목·제4호 라목)  \n'
#  '6) 장학금 중 대학(고등교육법상)생이 근로 대가로 받는 장학금(서목)  \n'
#  '7) 직무발명보상금(발명진흥법상)으로서 대통령령이 정하는 금액(어목)  \n'
#  '8) 연장·야간·휴일근로수당 중 대통령령이 정하는 생산직 등(더목)  \n'
#  '9) 사내급식 또는 월 20만원 이하 식사대(러목)  \n'
#  '10) 출산·6세 이하 자녀 보육 관련 사용자 지급금 월 20만원 이내(머목)  \n'
#  '11) 복리후생적 급여로서 대통령령이 정하는 것(저목)  \n'
#  '12) 종교인소득 중  \n'
#  '   - 학자금, 식사(대), 실비변상적 지급액  \n'
#  '   - 출산·보육 관련 월 20만원 이내 금품  \n'
#  '   - 기재부령이 정하는 사택 제공 이익(제3호 아목)\n'
#  '\n'
#  '다. 연금소득 관련(제12조 제4호)  \n'
#  '1) 공적연금 관련법에 따른 유족·장해·장애·상이·순직·위험직무 등 유족연금 및 연계노령·퇴직유족연금(가목)  \n'
#  '2) 산재보상보험법상 각종 연금(다목)  \n'
#  '3) 국군포로의 송환법에 따른 국군포로 연금(라목)\n'
#  '\n'
#  '라. 기타소득 관련(제12조 제5호 및 유사 조항)  \n'
#  '1) 국가유공자예우법·보훈보상법에 따른 보훈급여금·학습보조비(가목)  \n'
#  '2) 북한이탈주민 보호법에 따른 정착금·보로금 등(가목)  \n'
#  '3) 국가보안법에 따른 상금·보로금(나목·5호 나목)  \n'
#  '4) 국가보안법 상금·보로금(제3호 나목)  \n'
#  '5) 상훈법 훈장 관련 대통령령이 정하는 부상·상금(제3호 다목)  \n'
#  '6) 문화유산보존법에 따라 국가지정문화유산 서화·골동품 양도소득(제3호 바목)  \n'
#  '7) 박물관·미술관에 서화·골동품 양도로 발생하는 소득(제3호 사목)  \n'
#  '8) 보수를 받지 않는 위원회 위원 등이 받는 수당(제3호 자목)  \n'
#  '9) 공익신탁법에 따른 공익신탁 이익(제1호)\n'
#  '\n'
#  '3. 각 항목별 주요 한도·조건  \n'
#  '- 주택임대소득: 1주택(기준시가 12억 이하, 국내소재), 총수입 2천만원 이하, 2018 과세기간까지(제2호 나목)  \n'
#  '- 임목양도: 조림 5년 이상, 연 600만원 이하(제2호 마목)  \n'
#  '- 식사대·출산·보육지원: 월 20만원 한도(근로자 머목, 종교인 아목)  \n'
#  '- 직무발명보상금: 대통령령이 정하는 금액 한도, 특수관계자 제외(제3호 라목·어목)  \n'
#  '- 장학금: 대학생이 근로 대가로 받는 장학금만 비과세(제3호 서목)  \n'
#  '- 공익신탁·산재·공무상·보훈·국군포로 관련 급여·연금: 법령상 정해진 요건 충족 시 한도 없음\n'
#  '\n'
#  '이상이 소득세법 제12조가 정하고 있는 주요 비과세소득과 그 한도·조건입니다.')
#
# ==================================================
# === 기존 프롬프트로 답변 ===
# ('소득세법 제12조에 따르면, 다음과 같은 소득은 **비과세소득**으로 소득세를 부과하지 않습니다. 주요 내용을 정리하면 다음과 '
#  '같습니다:\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ **비과세소득의 주요 항목**\n'
#  '\n'
#  '#### 1. **공익신탁 이익**\n'
#  '- 「공익신탁법」에 따른 공익신탁의 이익\n'
#  '\n'
#  '#### 2. **사업소득 중 비과세 대상**\n'
#  '- **논·밭을 작물 생산에 이용하게 함으로써 발생하는 소득**\n'
#  '- **1주택자의 주택임대소득** (단, 기준시가 12억원 초과 주택이나 국외 주택 제외)\n'
#  '- **연 총수입 2천만원 이하 주택임대소득** (2018년 12월 31일 이전까지 한정)\n'
#  '- **농어가부업소득** (대통령령으로 정함)\n'
#  '- **전통주 제조 소득**\n'
#  '- **조림 5년 이상 임지의 임목 벌채·양도 소득** (연 600만원 이하)\n'
#  '- **작물재배업 소득**\n'
#  '- **어로·양식어업 소득**\n'
#  '\n'
#  '#### 3. **근로·퇴직소득 중 비과세 대상**\n'
#  '- **복무 중 병사의 급여**\n'
#  '- **법적 동원 근로자의 급여**\n'
#  '- **산업재해보상보험법에 따른 급여** (요양급여, 휴업급여 등)\n'
#  '- **근로기준법 등에 따른 보상금** (요양보상금, 장해보상금 등)\n'
#  '- **야간·연장·휴일근로 수당** (일부 대상자 한정)\n'
#  '- **식사 제공 또는 식사대** (월 20만원 이하)\n'
#  '- **출산·보육 관련 급여** (월 20만원 이하)\n'
#  '- **직무발명보상금** (일정 조건 충족 시)\n'
#  '- **복리후생적 급여** (대통령령으로 정함)\n'
#  '\n'
#  '#### 4. **연금소득 중 비과세 대상**\n'
#  '- **공적연금 관련법에 따른 유족연금, 장해연금, 상이연금 등**\n'
#  '- **산업재해보상보험법에 따른 연금**\n'
#  '- **국군포로에 대한 연금**\n'
#  '\n'
#  '#### 5. **기타소득 중 비과세 대상**\n'
#  '- **국가유공자 등에 대한 보훈급여금, 학습보조비**\n'
#  '- **북한이탈주민의 정착금, 보로금**\n'
#  '- **국가보안법에 따른 상금·보로금**\n'
#  '- **상훈법에 따른 훈장 부상금**\n'
#  '- **종교인 소득 중 일정 금액 이하의 지원금** (식사대, 출산·보육비, 사택 제공 등)\n'
#  '- **서화·골동품을 박물관·미술관에 양도한 소득**\n'
#  '- **국가지정문화유산 양도 소득**\n'
#  '\n'
#  '---\n'
#  '\n'
#  '이 외에도 **법령에 따라 위원회 등에서 무보수로 활동하는 자가 받는 수당**이나, **장학금 중 근로 대가가 아닌 대학생 장학금** '
#  '등도 비과세됩니다.\n'
#  '\n'
#  '필요하시면 특정 항목에 대해 더 자세히 설명드릴 수 있습니다.')
#
# ==================================================
# === 검색 방식 개선 테스트 ===
# === MMR 검색 결과 ===
# ('소득세법 제12조에 따른 비과세소득은 “소득의 종류”별로 정리하면 다음과 같습니다.  \n'
#  '(※ 아래 표는 조항 순서를 재배열·통합하여 가독성을 높인 것이며, 각 항목 뒤에 괄호로 ‘소득종류’를 표기했습니다.)\n'
#  '\n'
#  '1. 사업소득\n'
#  '   • 공익신탁 이익 (사업)  \n'
#  '   • 논·밭을 작물 생산에 이용하게 함으로써 발생하는 소득 (사업)  \n'
#  '   • 1주택 1세대 보유자의 주택임대소득(시가 12억 초과·국외주택 제외) (사업)  \n'
#  '   • 같은 과세기간 총임대료 2천만원 이하 주택임대소득 (2018.12.31.까지 끝난 과세기간만) (사업)  \n'
#  '   • 농어가부업소득(대통령령이 정하는 범위) (사업)  \n'
#  '   • 전통주 제조소득(대통령령이 정하는 범위) (사업)  \n'
#  '   • 조림 5년 이상 임지의 임목 벌채·양도소득(연 600만원 이하) (사업)  \n'
#  '   • 작물재배업·어로·양식어업 소득(대통령령이 정하는 범위) (사업)\n'
#  '\n'
#  '2. 근로·퇴직소득\n'
#  '   • 복무 중 병(兵) 급여 (근로)  \n'
#  '   • 법률에 따른 동원근무 급여 (근로)  \n'
#  '   • 산재보험 요양·휴업·장해·간병·유족·장의급여, 장해특별·유족특별급여 (근로·퇴직)  \n'
#  '   • 근로자·선원 및 유족이 받는 산재보험 성격의 보상금(요양·휴업·상병·일시·장해·유족·행방불명·소지품유실·장의·장제) '
#  '(근로·퇴직)  \n'
#  '   • 고용보험 실업급여·육아휴직급여·육아기단축급여·출산전후급여 (근로)  \n'
#  '   • 제대군인 전직지원금 (근로)  \n'
#  '   • 공무원·사립학교교직원·별정우체국 직원의 육아휴직수당(학교 사무직원 포함, 대통령령이 정하는 한도) (근로)  \n'
#  '   • 국민연금 사망·반환일시금(사망으로 받는 것만) (퇴직)  \n'
#  '   • 공무원·군인·사학·우체국·공무원재해보상 등 법령에 따른 공상요양비·요양급여·장해일시금·비공무상·비직무상 '
#  '장해일시금·장애보상금·사망조위금·사망보상금·유족·퇴직유족·퇴역유족·순직유족·직무상유족·위험직무순직유족·재해부조금·재난부조금·휴직급여 '
#  '(근로·퇴직)  \n'
#  '   • 대통령령이 정하는 복리후생적 급여 (근로)  \n'
#  '   • 법령·조례 위원회 위원(학술·예술원 회원 포함) 수당(보수를 받지 않는 자에 한함) (근로)\n'
#  '\n'
#  '3. 연금소득\n'
#  '   • 공적연금(국민·공무원·군인·사학·별정우체국·연계법) 유족·장해·장애·상이·순직·퇴직유족·퇴역유족·연계노령유족·연계퇴직유족연금 '
#  '(연금)  \n'
#  '   • 산재보험 각종 연금 (연금)  \n'
#  '   • 국군포로 연금 (연금)\n'
#  '\n'
#  '4. 기타소득\n'
#  '   • 국가유공자·보훈보상대상자 보훈급여·학습보조비 (기타)  \n'
#  '   • 북한이탈주민 정착금·보로금 및 그 밖의 금품 (기타)  \n'
#  '   • 국가보안법 상금·보로금 (기타)  \n'
#  '   • 상훈법 훈장 부상·대통령령이 정하는 상금·부상 (기타)  \n'
#  '   • 종업원 등 퇴직 후 사용자·산학협력단이 지급하는 직무발명보상금(대통령령이 정하는 한도, 특수관계인 제외) (기타)  \n'
#  '   • 국군포로 위로지원금·그 밖의 금품 (기타)  \n'
#  '   • 국가지정문화유산(서화·골동품) 양도소득 (기타)  \n'
#  '   • 박물관·미술관에 서화·골동품 양도소득 (기타)  \n'
#  '   • 종교관련종사자 비과세 항목  \n'
#  '     – 대통령령이 정하는 학자금 (기타)  \n'
#  '     – 대통령령이 정하는 식사·식사대 (기타)  \n'
#  '     – 실비변상적 지급액 (기타)  \n'
#  '     – 출산이나 6세 이하 자녀 보육관련 월 20만원 이내 금품 (기타)  \n'
#  '     – 기획재정부령이 정하는 사택 제공 이익 (기타)\n'
#  '\n'
#  '정리하자면, 상기 항목들은 모두 소득세법상 “비과세소득”에 해당하므로 과세 대상에서 제외됩니다.')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
